# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Привет!👋</b>
#
# Меня зовут Роман Абрамов, я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь реагировать на мои комментарии своими, выделяя их цветами и наиболее понравившимся тебе способом оформления, но явно  отличающимся от моих комментариев. Это нужно, чтобы не создавалась путаница😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы. Желтые замечания и рекомендации необязательны к исправлению - на то это и рекомендации. Они больше ориентированы на улучшение твоих навыков
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-и-первичный-анализ-данных" data-toc-modified-id="Загрузка-и-первичный-анализ-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка и первичный анализ данных</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Подготовка-текста" data-toc-modified-id="Подготовка-текста-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Подготовка текста</a></span></li><li><span><a href="#Подготовка-выборок-и-векторизация-текста" data-toc-modified-id="Подготовка-выборок-и-векторизация-текста-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Подготовка выборок и векторизация текста</a></span></li></ul></li></ul></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Решающее-дерево" data-toc-modified-id="Решающее-дерево-2.0.2"><span class="toc-item-num">2.0.2&nbsp;&nbsp;</span>Решающее дерево</a></span></li><li><span><a href="#CatBoostClassifier" data-toc-modified-id="CatBoostClassifier-2.0.3"><span class="toc-item-num">2.0.3&nbsp;&nbsp;</span>CatBoostClassifier</a></span></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-2.0.4"><span class="toc-item-num">2.0.4&nbsp;&nbsp;</span>Тестирование</a></span></li></ul></li></ul></li><li><span><a href="#BERT" data-toc-modified-id="BERT-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>BERT</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Выводы</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# # Проект для «Викишоп» с BERT

# %% [markdown]
# Интернет-магазин «Викишоп» запускает новый сервис. Теперь пользователи могут редактировать и дополнять описания товаров, как в вики-сообществах. То есть клиенты предлагают свои правки и комментируют изменения других. Магазину нужен инструмент, который будет искать токсичные комментарии и отправлять их на модерацию.
#
# Обучите модель классифицировать комментарии на позитивные и негативные. В вашем распоряжении набор данных с разметкой о токсичности правок.
#
# Постройте модель со значением метрики качества *F1* не меньше 0.75.
#
# **План по выполнению проекта:**
#
# 1. Загрузка и подготовка данных с помощью техники TF-IDF.
# 2. Обучение разных моделей, тестирование.
# 3. Классификация с помощью модели BERT.
# 4. Вывод по проекту.

# %%
# pip install pymystem3
# pip install catboost
# pip install torch
# pip install transformers
# pip install wordcloud

# %%
# conda install -c conda-forge wordcloud

# %%
# Импорт библиотек
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords as nltk_stopwords
from nltk.stem import WordNetLemmatizer
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.sparse import vstack

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, RandomizedSearchCV, PredefinedSplit
from sklearn.metrics import f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier
from sklearn.svm import SVC

import re

from catboost import CatBoostClassifier, Pool

from tqdm import notebook 
import torch
import transformers
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from nltk.probability import FreqDist


from wordcloud import WordCloud, ImageColorGenerator

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Определение констант
SEED = 5555

# %% [markdown]
# ## Подготовка данных
#
# 1. Загрузка и изучение данных;
# 2. Подготовка данных к обучению моделей.

# %% [markdown]
# ### Загрузка и первичный анализ данных

# %%
try:
    df = pd.read_csv('/datasets/toxic_comments.csv')
except:
    df = pd.read_csv('C:/Users/USER/YandexDisk/My_progects/YP/nlp_progect/toxic_comments.csv')

# %%
df.head()
# Out:
#                                                 text  toxic
# 0  Explanation\nWhy the edits made under my usern...      0
# 1  D'aww! He matches this background colour I'm s...      0
# 2  Hey man, I'm really not trying to edit war. It...      0
# 3  "\nMore\nI can't make any real suggestions on ...      0
# 4  You, sir, are my hero. Any chance you remember...      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159571 entries, 0 to 159570
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   text    159571 non-null  object
#  1   toxic   159571 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Исследование баланса классов**

# %%
df['toxic'].hist(bins=2)
# Out:
# <AxesSubplot:>

# %%
df['toxic'].value_counts()
# Out:
# 0    143346
# 1     16225
# Name: toxic, dtype: int64

# %%
df[df['toxic'] == 1]['toxic'].count() / df[df['toxic'] == 0]['toxic'].count()
# Out:
# 0.1131876717871444

# %% [markdown]
# **Длинна коментария**

# %%
pd.DataFrame(data=[[df[df['toxic'] == 1]['text'].apply(len).mean(), df[df['toxic'] == 0]['text'].apply(len).mean()],
                   [df[df['toxic'] == 1]['text'].apply(len).median(), df[df['toxic'] == 0]['text'].apply(len).median()]],
             index=['средняя длинна','медианная длинна'],
             columns=['Токсичный','Не токсичный']
            )
# Out:
#                    Токсичный  Не токсичный
# средняя длинна    303.304037    404.347174
# медианная длинна  128.000000    216.000000

# %%
df[df['toxic'] == 1]['text'].apply(len).hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
df[df['toxic'] == 0]['text'].apply(len).hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Распределения длинны токсичных и не токсичных комментариев схожи, однако средняя длинна токсичного комментария на треть меньше чем не токсичного.

# %% [markdown]
# **Вывод**
#
# 1. Данные загружены и изучены. Столбец *text* в нём содержит текст комментария, а *toxic* — целевой признак.;
# 2. Пропусков и дубликатов в наборе данных нет;
# 3. Токсичных коментариев более чем в 10 раз меньше не токсичных;
# 4. Распределения длинны токсичных и не токсичных комментариев схожи, однако средняя длинна токсичного комментария на треть меньше чем не токсичного.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Стоило бы посмотреть распределение классов на дисбаланс
#
# Как улучшить EDA:
#
# Можно было бы добавить распределение самых встречаемых слов / облако слов. Посмотреть на самые встречаемые слова в 2х классах и т.п. Отличный гайд доступен по ссылке. Это необходимо для того, чтобы понимать, с чем же придется работать.
#
# https://towardsdatascience.com/nlp-part-3-exploratory-data-analysis-of-text-data-1caa8ab3f79d

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Добавил проверку дизбаланса и анализ распределения длин комментариев. Вообще, дизбаланс я ранее исследовал, но попытка с ним побороться несколькими способами не дала никакого эффекта. Облако самых встречаемых слов добавил в следующем разделе уже после лемматизации и очистки текста. Так облако более информативно.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 итерация <a class="tocSkip"> </h2>
#
# Согласен с облаком после лемматизации. Самый действенный способ для текстов - наверное, веса для функции оптимизации, то есть веса классов. Хотя можно попробовать и другие методы для экспериментального подтверждения.

# %% [markdown]
# ### Подготовка данных
#
# Подготовку данных произведём в следующей последовательности:
# 1. Подготовка текста;
# 2. Подготовка выборок;
# 3. Векторизация текста.

# %% [markdown]
# #### Подготовка текста
#
# Применим к текстовым данным следующие инструменты подготовки текста:
# 1. Очистку от лишних символов;
# 2. Лематизацию;
# 3. Удаление стоп-слов.
#
# После подготовки текстовых данных, проаналтзируем какие слова чаще всего встречаются в токсичных и в не токсичных комментариях

# %%
# %%time
# Очистка текста
wnl = WordNetLemmatizer()
stopwords = set(nltk_stopwords.words('english'))
# очистка с лематизацией
features = df['text'].apply(lambda x: ' '.join([wnl.lemmatize(re.sub(r'[^a-zA-Z]', ' ', i).lower()) for i in x.split()]))
# Out:
# CPU times: total: 38.8 s
# Wall time: 38.9 s

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Неплохо было бы верифицировать, что лемматизация сработала. Хотя бы с помощью визуального анализа. В данном случае у тебя используется лемматизатор, который не работает с латинскими символами (они представляют большинство в этой задаче), поэтому лучше поискать другой инструмент
#
#
# https://www.geeksforgeeks.org/python-lemmatization-approaches-with-examples/

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Примнил другой лемматизатор. Заработало!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 итерация <a class="tocSkip"> </h2>
#
# Супер

# %%
# До очистки
df['text'].head(10)
# Out:
# 0    Explanation\nWhy the edits made under my usern...
# 1    D'aww! He matches this background colour I'm s...
# 2    Hey man, I'm really not trying to edit war. It...
# 3    "\nMore\nI can't make any real suggestions on ...
# 4    You, sir, are my hero. Any chance you remember...
# 5    "\n\nCongratulations from me as well, use the ...
# 6         COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK
# 7    Your vandalism to the Matt Shirvington article...
# 8    Sorry if the word 'nonsense' was offensive to ...
# 9    alignment on this subject and which are contra...
# Name: text, dtype: object

# %%
# После очистки
features.head(10)
# Out:
# 0    explanation why the edits made under my userna...
# 1    d aww  he match this background colour i m see...
# 2    hey man  i m really not trying to edit war  it...
# 3      more i can t make any real suggestion on imp...
# 4    you  sir  are my hero  any chance you remember...
# 5      congratulation from me a well  use the tool ...
# 6         cocksucker before you piss around on my work
# 7    your vandalism to the matt shirvington article...
# 8    sorry if the word  nonsense  wa offensive to y...
# 9    alignment on this subject and which are contra...
# Name: text, dtype: object

# %% [markdown]
# **Распределение слов по классам комментариев**

# %%
def toxic_cloud(text, label):
    """ Принимаем список комментариев и заголовок
        Рассчитываем топ 100 слов из списка
        Выводим на экран облако слов
    """
    # Составляем список всех слов из принятых комментариев
    words = []
    for wordlist in text:
        words += wordlist.split()
    # Очищаем их от стоп-слов
    clear_words = []    
    for word in words:
        if word not in stopwords:
            clear_words.append(word)
    # Составляем список 100 самых частых слов
    mostcommon = FreqDist(clear_words).most_common(100)

    # Создаём облако слов и выводим на экран
    wordcloud = WordCloud(width=600, height=300, background_color='white').generate(str(mostcommon))
    fig = plt.figure(figsize=(18,7), facecolor='white')
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis('off')
    plt.title(label, fontsize=30)
    plt.tight_layout(pad=0)
    plt.show()

# %%
# Toп 100 слов в токсичных комментариях
toxic_cloud(features[df['toxic'] == 1],'Toп 100 слов в токсичных комментариях')

# %%
# Toп 100 слов в не токсичных комментариях
toxic_cloud(features[df['toxic'] == 0],'Toп 100 слов в нейтральных комментариях')

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Стоило ещё бы привести все слова в нижний регистр - так уменьшиться количество уникальных слов и наше векторное пространство будет меньше

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Перевёл в нижний регистр.
# </div>

# %% [markdown]
# #### Подготовка выборок и векторизация текста
#
# Разделим набор данных на выборки:
#    - Тренировочную - 80%;
#    - Валидационную - 10%;
#    - Тестовую      - 10%.
#
# После разделения данных, обучим векторизатор на тренировочной выборке, затем векторизируем валидационную и тестовую выборки. Параметры векторизатора были определены опытным путём: размер n-грам = (1,2), максимальный размер вектора = 50 000.

# %%
# %%time
# Создаём выборки

features_train, features_valid, target_train, target_valid = train_test_split(features, 
                                                                              df['toxic'], 
                                                                              test_size=0.2, 
                                                                              random_state=SEED)
features_valid, features_test, target_valid, target_test = train_test_split(features_valid, 
                                                                            target_valid, 
                                                                            test_size=0.5, 
                                                                            random_state=SEED)
# Векторизация текста
vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=50000)#, stop_words=stopwords)

features_train_vect = vectorizer.fit_transform(features_train)
features_valid_vect = vectorizer.transform(features_valid)
features_test_vect = vectorizer.transform(features_test)

# проверим размеры выборок
pd.DataFrame(data=[features_train_vect.shape, target_train.shape,
                   features_valid_vect.shape, target_valid.shape,
                   features_test_vect.shape,  target_test.shape
                  ],
             index=['features_train', 'target_train', 
                    'features_valid', 'target_valid', 
                    'features_test',  'target_test'],
             columns=['Индексы', 'Колонки']
            )
# Out:
# CPU times: total: 20.4 s
# Wall time: 20.5 s
#                 Индексы  Колонки
# features_train   127656  50000.0
# target_train     127656      NaN
# features_valid    15957  50000.0
# target_valid      15957      NaN
# features_test     15958  50000.0
# target_test       15958      NaN

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!👍:</b>
#
# Молодец, что разбиваешь выборки на 3 части. В данной задаче у нас довольно много записей, поэтому использовать 60 - 20 - 20 слегка много для тестового и валидационного набора. Для них можно оставить всего по паре тысячи записей, остальное важнее для использования в тренировочном наборе данных.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Немного изменил размеры выборок: 80/10/10
# </div>

# %% [markdown]
# **Вывод:**
#
# Анализ комментариев показал следующие особенности:
# 1. Токсичных комментариев более чем в 10 раз меньше чем нейтральных;
# 2. Длина токсичных комментариев, в среднем, меньше чем не токсичных;
# 3. Наиболее употребляемые слова:
#     - в токсичных комментариях: `fuck`, `suck`, `wikipedia`(не знал что wikipedia - ругательство!);
#     - в нейтральных комментариях: `article`, `page`, `wa`(видимо имеется в виду сокращение от Washington.)
#
# Данные подготовлены к обучению моделей.

# %% [markdown]
# ## Обучение
#
# Обучим несколько моделей с подбором гиперпараметров:
# - Логистическую регрессию;
# - Классификатор на основе решающего дерева;
# - CatBoostClassifier.
#
# Для исключения дублирования кода создадим две функции:
# - Функция `get_f1_valid` принимает модель и выборки, возвращает значение метрики F1;
# - Функция `get_f1_cv` приниает модель параметры и выборки, возвращает лучшие параметры модели и лучший F1.

# %%
def get_f1_valid(model, X, y, X_test, y_test):
    """ Принимаем модель,
        возвращаем f1 
    """
    model.fit(X, y)
    predictions = model.predict(X_test)
     
    return round(f1_score(y_test, predictions), 3)

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Тут все же не стоит делать такое явное указание стандартных параметров - лучше передавать их обязательно. Функция должна быть самодостаточна, а сейчас она слишком вплетена в сам код и при её вызове непонятно, что ты туда что-то передаешь - уменьшает читабельность кода и так легче сделать ошибку в будущем.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> ОК, поправил.
# </div>

# %%
def get_f1_cv(model, 
              parametrs, 
              X=vstack((features_train_vect, features_valid_vect)), 
              y=pd.concat([target_train, target_valid])):
    """ Принимаем модель,
        возвращаем f1 
    """
    validation_set_indexes = [-1]*features_train_vect.shape[0] + [0]*features_valid_vect.shape[0]
    ps = PredefinedSplit(test_fold=validation_set_indexes)
    
    rs = RandomizedSearchCV(model, 
                            parametrs, 
                            scoring='f1', 
                            cv=ps,
                            random_state = SEED,
                            n_jobs=-1
                           )
    rs.fit(X, y)
    
    return round(rs.best_score_, 3), rs.best_params_

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Все же лучше остановиться на чем-то одном. Если используешь 3 набора данных, то не стоит использовать кросс валидацию. Проблема в том, что модель на кросс валидации, когда объединяешь наборы, все же видит часть данных из того, на чем потом валидируешь - это проблема. Если уже разделил выборки, то можешь использовать PredefinedSplit и передавать его в качестве параметра для различных Search вместо кросс валидации
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.PredefinedSplit.html#sklearn.model_selection.PredefinedSplit

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b>  Добавил PredefinedSplit. Получается, это уже подбор параметров без кросс-валидации.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 итерация <a class="tocSkip"> </h2>
#
# Верно

# %% [markdown]
# #### Логистическая регрессия

# %%
# %%time
get_f1_valid(LogisticRegression(max_iter=2000, random_state=SEED), 
             X=features_train_vect, 
             y=target_train, 
             X_test=features_valid_vect, 
             y_test=target_valid
            )
# Out:
# CPU times: total: 17.4 s
# Wall time: 4.4 s
# 0.731

# %%
# %%time
# Подбор коэфициента регуляризации
get_f1_cv(LogisticRegression(max_iter=2000, random_state=SEED),
          {'C':[2,3,4,5,7,10,15,20,40,50]}
         )
# Out:
# CPU times: total: 50.6 s
# Wall time: 1min 15s
# (0.783, {'C': 10})

# %%
# %%time
# Модель с подобранными гиперпараметрами
get_f1_valid(LogisticRegression(max_iter=2000, C=10, random_state=SEED), 
             X=features_train_vect, 
             y=target_train, 
             X_test=features_valid_vect, 
             y_test=target_valid
            )
# Out:
# CPU times: total: 43.7 s
# Wall time: 11 s
# 0.783

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Можно определить 5555 как константу в самом начале и после использовать её - так меньше шансов ошибиться и выглядит более читабельно.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Сделал.
# </div>

# %% [markdown]
# **Вывод:** Логистическая регрессия с регуляризацией успешно справляется с поставленной задачей

# %% [markdown]
# #### Решающее дерево

# %%
# %%time
get_f1_valid(DecisionTreeClassifier(max_depth=30, random_state=SEED), 
             X=features_train_vect, 
             y=target_train, 
             X_test=features_valid_vect, 
             y_test=target_valid
            )
# Out:
# CPU times: total: 29.1 s
# Wall time: 28.8 s
# 0.667

# %%
# %%time
# Подбор максимальной глубины дерева
get_f1_cv(DecisionTreeClassifier(random_state=SEED),
          {'max_depth': range(2,50)}
         )
# Out:
# CPU times: total: 46.1 s
# Wall time: 2min 5s
# (0.683, {'max_depth': 42})

# %%
# %%time
# Модель с подобранными гиперпараметрами
get_f1_valid(DecisionTreeClassifier(max_depth=42, random_state=SEED), 
             X=features_train_vect, 
             y=target_train, 
             X_test=features_valid_vect, 
             y_test=target_valid
            )
# Out:
# CPU times: total: 40.7 s
# Wall time: 40.8 s
# 0.683

# %% [markdown]
# **Вывод:** С помощью решающего дерева не удаётся добиться заданного качества классификации

# %% [markdown]
# #### CatBoostClassifier
#
# Данную модель обучим в двух вариантах:
# 1. Как и предъидущие модели, на векторизированных текстовых данных;
# 2. На необработанных текстовых данных.

# %% [markdown]
# **CatBoostClassifier на векторизированных текстовых данных**

# %%
# %%time
# Обучение модели на векторизированном тексте
get_f1_valid(CatBoostClassifier(silent=True, iterations=500, random_state=SEED), 
             X=features_train_vect, 
             y=target_train, 
             X_test=features_valid_vect, 
             y_test=target_valid
            )
# Out:
# CPU times: total: 1h 43min 12s
# Wall time: 14min 48s
# 0.764

# %% [markdown]
# CatBoostClassifier достигает заданного порога качества. Искать оптимальные гиперпараметры для данной модели, на мой взгляд, смысла не имеет, так как, обычно модель CatBoost сильно улучшить не удаётся.

# %% [markdown]
# **CatBoostClassifier на необработанных текстовых данных**
#
# Попробуем обучить модель классификации CatBoost на невекторизированных текстовых данных.

# %%
def fit_model(train_pool, test_pool, **kwargs):
    """ Принимаем тренировочный и тестовый пул, а также параметры модели.
        Возвращаем обученную модель
    """
    model = CatBoostClassifier(#task_type='GPU',
                               iterations=5000,
                               eval_metric='F1',
                               od_type='Iter',
                               od_wait=500,
                               **kwargs
                              )
    return model.fit(train_pool,
                     eval_set=test_pool,
                     verbose=100,
                     plot=True,
                     use_best_model=True)

# %%
# Тренировочный пул
train_pool = Pool(data=features_train,
                  label=target_train,
                  feature_names=['text'],
                  text_features=['text']
                 )
# Тестовый пул
valid_pool = Pool(data=features_valid.values,
                   label=target_valid.values,
                   feature_names = ['text'],
                   text_features=['text']
                  )

# %%
# %%time
# Обучаем модель
model = fit_model(train_pool, valid_pool,
                  learning_rate=0.35,
                  tokenizers=[
                  {'tokenizer_id': 'Sense',
                   'separator_type': 'BySense',
                   'lowercasing': 'True',
                   'token_types':['Word', 'Number', 'SentenceBreak'],
                   'sub_tokens_policy':'SeveralTokens'
                  } 
                ],
                 dictionaries = [
                {'dictionary_id': 'Word',
                 'max_dictionary_size': '50000'
                }
                 ],
                 feature_calcers = [
                'BoW:top_tokens_count=10000'
                 ]
                )
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.4259557	test: 0.4305949	best: 0.4305949 (0)	total: 230ms	remaining: 19m 11s
# 100:	learn: 0.7645260	test: 0.7369565	best: 0.7391779 (89)	total: 28.1s	remaining: 22m 41s
# 200:	learn: 0.8000354	test: 0.7545710	best: 0.7545710 (200)	total: 56s	remaining: 22m 17s
# 300:	learn: 0.8237956	test: 0.7670948	best: 0.7670948 (300)	total: 1m 23s	remaining: 21m 46s
# 400:	learn: 0.8394041	test: 0.7689119	best: 0.7702936 (383)	total: 1m 52s	remaining: 21m 31s
# 500:	learn: 0.8539834	test: 0.7692835	best: 0.7715072 (455)	total: 2m 21s	remaining: 21m 10s
# 600:	learn: 0.8632464	test: 0.7749658	best: 0.7749658 (597)	total: 2m 49s	remaining: 20m 37s
# 700:	learn: 0.8695873	test: 0.7749404	best: 0.7770570 (607)	total: 3m 16s	remaining: 20m 7s
# 800:	learn: 0.8770306	test: 0.7767189	best: 0.7770961 (765)	total: 3m 45s	remaining: 19m 39s
# ...

# %% [markdown]
# **Вывод:** CatBoostClassifier обученныё на необработанных текстовых данных показывает лучшее качество по сравнению с той-же моделью, но на векторизированных данных.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Можно было попробовать ещё некоторые простые ML модели, прежде чем доставать более сложный градиентный бустинг, например, SVM или NaiveBayes.
#
# Кстати, CatBoost поддерживает работу с текстом "из коробки" - можно было попробовать такой метод. Если интересно, то тут с примером и сравнение с BERT для похожей задачи.
#
# https://towardsdatascience.com/unconventional-sentiment-analysis-bert-vs-catboost-90645f2437a9

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Попытался добавить SVM или NaiveBayes. SVM оочень долго учиться, а NaiveBayes не хочет дружить со sparce matrix. Думаю, что я достаточно моделек тут использовал.
#     Спасибо за подсказку про CatBoost с текстом из коробки! Именно этот пример я как-то неудачно пытался воспроизвести. А сейчас всё получилось!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 итерация <a class="tocSkip"> </h2>
#
# Cупер - молодец!

# %% [markdown]
# **Вывод**
#
# Из обученных моделей лучшее качество показала модель CatBoostClassifier, обученная на необработанных текстовых данных. Однако, она показала качество не значительно лучше чем Логистическая регресся, а время её обучения примерно в 100 раз больше.

# %% [markdown]
# #### Тестирование
#
# 1. Протестируем лучшую модель на тестовой выборке.
# 2. Сравинм работу модели с фиктивным классификатором.

# %%
# %%time
get_f1_valid(LogisticRegression(max_iter=2000, C=10, random_state=SEED),
             X=vstack((features_train_vect, features_valid_vect)), 
             y=pd.concat([target_train, target_valid]),
             X_test=features_test_vect,
             y_test=target_test
            )
# Out:
# CPU times: total: 55.4 s
# Wall time: 14.2 s
# 0.788

# %%
get_f1_valid(DummyClassifier(strategy='most_frequent'),
             X=vstack((features_train_vect, features_valid_vect)), 
             y=pd.concat([target_train, target_valid]),
             X_test=features_test_vect,
             y_test=target_test
            )
# Out:
# 0.0

# %% [markdown]
# **Вывод**
#
# Модель Логистическая регрессия на тестовой выборке показала такое-же качество как и на валидационной. Кроме того, константная модель не может с ней соперничать. На качество модели повлияли не только подобраннные гиперпараметры самой модели, но и подготовка данных. Так, опытным путём были подобраны параметры векторизации, способы очистки и лематизации исходных данных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Согласен. Плюс за сравнение с наивным заполнением - молодец!

# %% [markdown]
# ## BERT
#
# Решим задачу классификации коментариев на токсичные и не токсичные с помощью модели BERT. Последовательность действий будет следующая:
# 1. Загрузим предобученные токенизатор и модель создания ембендингов с сайта https://huggingface.co/unitary/toxic-bert/tree/main
# 2. Преобразуем текст в токены с помощью предобученного токенизатора;
# 3. Создадим эмбендинги с помощью предобученной модели;
# 4. Применим модель классификации к преобразованным данным.
#
# Так как модель BERT требует больших вычислительных ресурсов, работать будем с выборкой из всего набора данных равной 1000 строк.

# %%
# Загрузка токенизатора и модели создания эмбендингов
tokenizer = AutoTokenizer.from_pretrained("unitary/toxic-bert")

model = AutoModelForSequenceClassification.from_pretrained("unitary/toxic-bert")

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Плюс за использование не стандартной модели, а обученной специально для этой задачи

# %%
# Создаём выборку из набора данных
df_sample = df.sample(1000).reset_index(drop=True)

# %%
# Преобразуем текст в тензоры
# так как в представленной модели максимальный размер тензоров = 512, придётся обрезать наши данные до этого значения
tokenized = df_sample['text'].apply(lambda x: tokenizer.encode(x, add_special_tokens=True, truncation=True))
# Заполним остатки данных нулями
padded = np.array([i + [0]*(512 - len(i)) for i in tokenized.values])
# Зададим маску
attention_mask = np.where(padded != 0, 1, 0)

# %%
# Проверим размер
padded.shape
# Out:
# (1000, 512)

# %%
# Создаём эмбендинги
batch_size = 100
embeddings = []
for i in notebook.tqdm(range(padded.shape[0] // batch_size)):
        batch = torch.LongTensor(padded[batch_size*i:batch_size*(i+1)])
        attention_mask_batch = torch.LongTensor(attention_mask[batch_size*i:batch_size*(i+1)])
        
        with torch.no_grad():
            batch_embeddings = model(batch, attention_mask=attention_mask_batch)

        embeddings.append(batch_embeddings[0].numpy())
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
# Создаём выборки для модели классификации
features_bert = np.concatenate(embeddings)
target_bert = df_sample['toxic']

features_train_bert, features_test_bert, target_train_bert, target_test_bert = train_test_split(features_bert, 
                                                                                                target_bert, 
                                                                                                test_size=0.5, 
                                                                                                random_state=5555)

# %%
# %%time
# Обучаем модель и получаем результат
get_f1_valid(LogisticRegression(max_iter=2000, random_state=5555),
             X=features_train_bert, 
             y=target_train_bert,
             X_test=features_test_bert,
             y_test=target_test_bert
            )
# Out:
# CPU times: total: 78.1 ms
# Wall time: 17.9 ms
# 0.93

# %% [markdown]
# **Вывод**
#
# Даже на уменьшеной до 1000 закписей выборке, классификация на преобразованных с помощью модели BERT данных показывает результат гораздо лучший чем с помощью техники TF-IDF. Это объясняет как важен смысл слова и его контекст по сравнению с простой частотой и важностью слов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Согласен. BERT в данном случае работает так хорошо, потому что был натренирован на этой задаче. Если использовать стандартный BERT, то его возможности и результаты будут не столь потрясающи

# %% [markdown]
# ## Выводы

# %% [markdown]
# В проекте было применено два подхода к преобразованию текстовых данных: векторизация TF-IDF и модель BERT. Также протестирована модель CatBoost со встроенным преобразованием текста. Наилучшее качество классификации удалось достичь с помощью модели BERT. Векторизация TF-IDF также позволила достичь заданного качества классификации. Модель CatBoost со встроенным преобразованием текста показала немного лучший результат чем линейная модель, но вычислительных мощьностей она потребовала в разы больше. По качеству и скорости обучения лучше остальных себя показала Логистическая регрессия с коэфициентом С=10.
#
# Главный вывод по проекту:
# 1. Если требуется высокое качество классификации, то необходимо преобразовывать текстовые данные с помощью модели BERT. За это мы расплатимся более высокими требованиями к вычислительным мощьностям.
# 2. Если можно обойтись немного меньшим качеством классификации, либо мы не располагаем необходимыми вычислительными мощьностяим, то можно применить менее требовательный к железу способ преобразования текста TF-IDF и модель классификации Логистическая регрессия.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту (комментарий ревьера)**
#
# Спасибо за твой проект! Есть несколько моментов, помеченных красным, которые стоит исправить. Если хочешь получить ещё больше опыта - попробуй воспользоваться частью советов из желтых комментариев. В целом, логика проекта верна, так что уверен, что тебе не составит труда исправить все остальное.
#
# **Отмечу отдельные положительные моменты проекта🙂**:
#
# * Использование TF-IDF и BERT
# * Подбор гиперпараметров для множества моделей
# * Использование предобученного на схожей задаче BERT
# * Сравнение с наивным заполнением
#
# **На что стоит обратить внимание🤓**:
#
# * Стоит проводить более детальный анализ данных перед работой - так можно понять проблемы, с которыми придется столкнуться. Например, дисбаланс классов
# * Лучше делать визуальный анализ манипуляций с данными - это самый простой способ убедиться, что код работает
# * Остальные рекомендации ты найдешь в моих комментариях!
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Спасибо за качественную проверку и советы! Постарался все отработать.
# </div>

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Данные загружены и подготовлены
# - [x]  Модели обучены
# - [x]  Значение метрики *F1* не меньше 0.75
# - [x]  Выводы написаны
